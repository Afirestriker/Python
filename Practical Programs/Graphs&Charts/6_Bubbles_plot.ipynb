# %%
# Bubbles Plot program

#Program 1: Sample Bubbles scatter plot

# %%
#Bubbles Scatter Plot
#Program 1: Sample Bubbles scatter plot

import matplotlib.pyplot as plt
import numpy as np

# create data
x = np.random.rand(20)
y = np.random.rand(20)
z = np.random.rand(20)
colors = np.random.rand(20)

#use the scatter function
plt.scatter(x, y, s=y*1000, c=colors)
plt.colorbar()
plt.show()
